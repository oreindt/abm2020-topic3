# %% [markdown]
# # Plots

# %% [markdown]
# Use the `Plots` package.

# %%
using Plots; gr() # Using the Plotly Backend

# %% [markdown]
# Include the file with the simulation setup.

# %%
include("setup.jl")
# Out:
# LoadError: LoadError: invalid redefinition of constant SimplePerson
# in expression starting at C:\Users\or\Documents\code\abmcourse\abm2020-topic3\julia\model.jl:4
# in expression starting at C:\Users\or\Documents\code\abmcourse\abm2020-topic3\julia\setup.jl:1
#
# Stacktrace:
#  [1] top-level scope at C:\Users\or\Documents\code\abmcourse\abm2020-topic3\julia\model.jl:4
#  [2] include(::String) at .\client.jl:457
#  [3] top-level scope at C:\Users\or\Documents\code\abmcourse\abm2020-topic3\julia\setup.jl:1
#  [4] include(::String) at .\client.jl:457
#  [5] top-level scope at In[7]:1
#  [6] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [7] execute_code(::String, ::String) at C:\Users\or\.julia\packages\IJulia\a1SNk\src\execute_request.jl:27
#  [8] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\or\.julia\packages\IJulia\a1SNk\src\execute_request.jl:86
#  [9] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [10] invokelatest at .\essentials.jl:709 [inlined]
#  [11] eventloop(::ZMQ.Socket) at C:\Users\or\.julia\packages\IJulia\a1SNk\src\eventloop.jl:8
#  [12] (::IJulia.var"#15#18")() at .\task.jl:356

# %% [markdown]
# Create a plot.

# %%
sim = setup_sim(p=0.1, N=1000, p_c=1.0, n_inf=10, b=0, seed=42)
knowing, pos, neg, mid, avg_belief, abs_avgs = run_sim(sim, 500)

Plots.plot([knowing pos neg mid avg_belief abs_avgs], labels = ["knowing" "highly pos" "highly neg" "mid" "avg belief" "abs average"])
